# %% [markdown]
# ## Text to Speech Speecht5

# %%
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech
from datasets import load_dataset
import torch
import soundfile as sf
# Out:
# c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
processor = SpeechT5Processor.from_pretrained("../Models/speecht5_tts")

# %%
model = SpeechT5ForTextToSpeech.from_pretrained("../Models/speecht5_tts")

# %%
from transformers import SpeechT5HifiGan

# %%
vocoder = SpeechT5HifiGan.from_pretrained("../Models/speecht5_hifigan")

# %%
inputs = processor(text="I love Pakistan and Hindustan and Germany and Japan.", return_tensors="pt")

# %%
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")

# %%
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

# %%
speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

# %%
sf.write("speech.wav", speech.numpy(), samplerate=16000)

# %%
from IPython.display import Audio

Audio(speech, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Speech-to-speech for voice conversion (Cloning)

# %%
from transformers import SpeechT5ForSpeechToSpeech

# %%
processor = SpeechT5Processor.from_pretrained("../Models/speecht5_vc")
model = SpeechT5ForSpeechToSpeech.from_pretrained("../Models/speecht5_vc")
# Out:
# Some weights of SpeechT5ForSpeechToSpeech were not initialized from the model checkpoint at ../Models/speecht5_vc and are newly initialized: ['speecht5.encoder.prenet.pos_sinusoidal_embed.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Load an input speech example:
dataset = load_dataset("hf-internal-testing/librispeech_asr_demo", "clean", split="validation", trust_remote_code=True)
dataset = dataset.sort("id")
example = dataset[40]

# %%
Audio(example["audio"]["array"], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Preprocess the speech input:
sampling_rate = dataset.features["audio"].sampling_rate
inputs = processor(audio=example["audio"]["array"], sampling_rate=sampling_rate, return_tensors="pt")

# %%
# Load the speaker embedding for the target speaker's voice:
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

# %%
# Generate the speech:
speech = model.generate_speech(inputs["input_values"], speaker_embeddings, vocoder=vocoder)

# %%
Audio(speech, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import soundfile as sf
sf.write("speech_converted.wav", speech.numpy(), samplerate=16000)

# %% [markdown]
# ## Automatic speech recognition (using the model)

# %%
from transformers import SpeechT5ForSpeechToText

# %%
processor = SpeechT5Processor.from_pretrained("../Models/speecht5_asr")
model = SpeechT5ForSpeechToText.from_pretrained("../Models/speecht5_asr")
# Out:
# Some weights of SpeechT5ForSpeechToText were not initialized from the model checkpoint at ../Models/speecht5_asr and are newly initialized: ['speecht5.encoder.prenet.pos_sinusoidal_embed.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# example = "./harvard.wav"
example = dataset[40]

# %%
# Preprocess the input speech example:
sampling_rate = dataset.features["audio"].sampling_rate
inputs = processor(audio=example["audio"]["array"], sampling_rate=sampling_rate, return_tensors="pt")

# %%
# Generate text from the speech input:
predicted_ids = model.generate(**inputs, max_length=100)
transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)

# %%
transcription[0]
# Out:
# 'a man said to the universe sir i exist'

# %%
import torch
from transformers import SpeechT5Processor, SpeechT5ForSpeechToText
import soundfile as sf
import speech_recognition as sr
import numpy as np
import librosa
import warnings

# %%
def load_model_and_processor(model_path):
    processor = SpeechT5Processor.from_pretrained(model_path)
    model = SpeechT5ForSpeechToText.from_pretrained(model_path)
    return processor, model

# %%
def resample_if_necessary(audio_array, orig_sr, target_sr=16000):
    if orig_sr != target_sr:
        audio_array = librosa.resample(audio_array, orig_sr=orig_sr, target_sr=target_sr)
    return audio_array

# %%
def transcribe_audio(audio_array, sampling_rate, processor, model):
    audio_array = resample_if_necessary(audio_array, sampling_rate)
    
    # Ensure the audio is long enough (pad if necessary)
    if len(audio_array) < 16000:
        audio_array = np.pad(audio_array, (0, 16000 - len(audio_array)))
    
    inputs = processor(audio=audio_array, sampling_rate=16000, return_tensors="pt")
    
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        predicted_ids = model.generate(**inputs, max_length=100)
    
    transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)
    return transcription[0]

# %%
def transcribe_from_file(file_path, processor, model):
    audio_array, sampling_rate = sf.read(file_path)
    return transcribe_audio(audio_array, sampling_rate, processor, model)

# %%
model_path = "../Models/speecht5_asr"
processor, model = load_model_and_processor(model_path)
# Out:
# Some weights of SpeechT5ForSpeechToText were not initialized from the model checkpoint at ../Models/speecht5_asr and are newly initialized: ['speecht5.encoder.prenet.pos_sinusoidal_embed.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
file_path = "harvard.wav"  # Replace with your audio file path
print("Transcribing from file:")
print(transcribe_from_file(file_path, processor, model))
# Out:
# Transcribing from file:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[65], line 3
#       1 file_path = "harvard.wav"  # Replace with your audio file path
#       2 print("Transcribing from file:")
# ----> 3 print(transcribe_from_file(file_path, processor, model))
#
# Cell In[62], line 3, in transcribe_from_file(file_path, processor, model)
#       1 def transcribe_from_file(file_path, processor, model):
#       2     audio_array, sampling_rate = sf.read(file_path)
# ----> 3     return transcribe_audio(audio_array, sampling_rate, processor, model)
#
# Cell In[61], line 12, in transcribe_audio(audio_array, sampling_rate, processor, model)
#      10 with warnings.catch_warnings():
#      11     warnings.simplefilter("ignore")
# ---> 12     predicted_ids = model.generate(**inputs, max_length=100)
#      14 transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)
#      15 return transcription[0]
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\transformers\generation\utils.py:1696, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1690     model_kwargs["attention_mask"] = self._prepare_attention_mask_for_generation(
#    1691         inputs_tensor, generation_config.pad_token_id, generation_config.eos_token_id
#    1692     )
#    1694 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1695     # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 1696     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1697         inputs_tensor, model_kwargs, model_input_name, generation_config
#    1698     )
#    1700 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1701 if self.config.is_encoder_decoder:
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\transformers\generation\utils.py:539, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     537 encoder_kwargs["return_dict"] = True
#     538 encoder_kwargs[model_input_name] = inputs_tensor
# --> 539 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     541 return model_kwargs
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\transformers\models\speecht5\modeling_speecht5.py:1407, in SpeechT5EncoderWithSpeechPrenet.forward(self, input_values, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#    1398 def forward(
#    1399     self,
#    1400     input_values: torch.FloatTensor,
#    (...)
#    1405     return_dict: Optional[bool] = None,
#    1406 ) -> Union[Tuple, BaseModelOutput]:
# -> 1407     hidden_states, attention_mask = self.prenet(input_values, attention_mask)
#    1409     outputs = self.wrapped_encoder(
#    1410         hidden_states=hidden_states,
#    1411         attention_mask=attention_mask,
#    (...)
#    1415         return_dict=return_dict,
#    1416     )
#    1418     return outputs
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\transformers\models\speecht5\modeling_speecht5.py:545, in SpeechT5SpeechEncoderPrenet.forward(self, input_values, attention_mask, mask_time_indices)
#     539 def forward(
#     540     self,
#     541     input_values: torch.Tensor,
#     542     attention_mask: Optional[torch.LongTensor] = None,
#     543     mask_time_indices: Optional[torch.FloatTensor] = None,
#     544 ):
# --> 545     extract_features = self.feature_encoder(input_values)
#     546     extract_features = extract_features.transpose(1, 2)
#     548     if attention_mask is not None:
#     549         # compute reduced attention_mask corresponding to feature vectors
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\transformers\models\speecht5\modeling_speecht5.py:497, in SpeechT5FeatureEncoder.forward(self, input_values)
#     492         hidden_states = self._gradient_checkpointing_func(
#     493             conv_layer.__call__,
#     494             hidden_states,
#     495         )
#     496     else:
# --> 497         hidden_states = conv_layer(hidden_states)
#     499 return hidden_states
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\transformers\models\speecht5\modeling_speecht5.py:277, in SpeechT5GroupNormConvLayer.forward(self, hidden_states)
#     276 def forward(self, hidden_states):
# --> 277     hidden_states = self.conv(hidden_states)
#     278     hidden_states = self.layer_norm(hidden_states)
#     279     hidden_states = self.activation(hidden_states)
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\conv.py:307, in Conv1d.forward(self, input)
#     306 def forward(self, input: Tensor) -> Tensor:
# --> 307     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\torch\nn\modules\conv.py:303, in Conv1d._conv_forward(self, input, weight, bias)
#     299 if self.padding_mode != 'zeros':
#     300     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     301                     weight, bias, self.stride,
#     302                     _single(0), self.dilation, self.groups)
# --> 303 return F.conv1d(input, weight, bias, self.stride,
#     304                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Calculated padded input size per channel: (1). Kernel size: (10). Kernel size can't be greater than actual input size

# %%
def transcribe_from_mic(processor, model):
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)
    
    # Use recognize_google for comparison
    try:
        google_transcription = r.recognize_google(audio)
        print("Google Speech Recognition thinks you said: ", google_transcription)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

    # Convert audio to numpy array
    audio_data = np.frombuffer(audio.get_raw_data(), dtype=np.int16)
    audio_float = audio_data.astype(np.float32) / 32768.0

    return transcribe_audio(audio_float, audio.sample_rate, processor, model)

# %%
print("\nTranscribing from microphone:")
print("SpeechT5 thinks you said:", transcribe_from_mic(processor, model))
# Out:
# Transcribing from microphone:
# Say something!
# Google Speech Recognition thinks you said:  I told the universe sir I exist
# i restore to universe serve i exist i exist i restore the universe

# %%
def transcribe_from_mic(processor, model):
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)
    
    # Use recognize_google for comparison
    try:
        google_transcription = r.recognize_google(audio)
        print("Google Speech Recognition thinks you said:", google_transcription)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

    # try:
    #     whisper_transcription = r.recognize_whisper(audio)
    #     print("Whisper Speech Recognition thinks you said:", whisper_transcription)
    # except sr.UnknownValueError:
    #     print("Whisper Speech Recognition could not understand audio")
    # except sr.RequestError as e:
    #     print("Could not request results from Whisper Speech Recognition service; {0}".format(e))

    # Convert audio to numpy array
    audio_data = np.frombuffer(audio.get_raw_data(), dtype=np.int16)
    
    # Resample to 16000 Hz
    audio_resampled = librosa.resample(audio_data.astype(np.float32), 
                                       orig_sr=audio.sample_rate, 
                                       target_sr=16000)
    
    # Normalize the audio
    audio_normalized = librosa.util.normalize(audio_resampled)

    # Process with SpeechT5
    inputs = processor(audio=audio_normalized, sampling_rate=16000, return_tensors="pt")
    predicted_ids = model.generate(**inputs)
    transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)

    return transcription[0]

# %%
model_path = "../Models/speecht5_asr"
processor, model = load_model_and_processor(model_path)

print("\nTranscribing from microphone:")
print("SpeechT5 thinks you said:", transcribe_from_mic(processor, model))
# Out:
# Some weights of SpeechT5ForSpeechToText were not initialized from the model checkpoint at ../Models/speecht5_asr and are newly initialized: ['speecht5.encoder.prenet.pos_sinusoidal_embed.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Transcribing from microphone:
# Say something!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[78], line 5
#       2 processor, model = load_model_and_processor(model_path)
#       4 print("\nTranscribing from microphone:")
# ----> 5 print("SpeechT5 thinks you said:", transcribe_from_mic(processor, model))
#
# Cell In[77], line 9, in transcribe_from_mic(processor, model)
#       7 # Use recognize_google for comparison
#       8 try:
# ----> 9     google_transcription = r.recognize_whisper(audio)
#      10     print("Google Speech Recognition thinks you said:", google_transcription)
#      11 except sr.UnknownValueError:
#
# File c:\Users\MicroZaib\miniconda3\envs\ryzenai-transformers\lib\site-packages\speech_recognition\__init__.py:1408, in Recognizer.recognize_whisper(self, audio_data, model, show_dict, load_options, language, translate, **transcribe_options)
#    1406 import soundfile as sf
#    1407 import torch
# -> 1408 import whisper
#    1410 if load_options or not hasattr(self, "whisper_model") or self.whisper_model.get(model) is None:
#    1411     self.whisper_model = getattr(self, "whisper_model", {})
#
# ModuleNotFoundError: No module named 'whisper'
